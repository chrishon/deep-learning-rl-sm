# %%
# !nvidia-smi
# Out:
# Sun Dec 15 05:36:24 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
###### libs for install ######


# !sudo apt-get update
# !sudo apt-get install gcc

# !sudo apt-get build-dep mesa
# !sudo apt-get install llvm-dev
# !sudo apt-get install freeglut3 freeglut3-dev

# !sudo apt-get install python3-dev

# !sudo apt-get install build-essential

# !sudo apt install curl git libgl1-mesa-dev libgl1-mesa-glx libglew-dev \
        libosmesa6-dev software-properties-common net-tools unzip vim \
        virtualenv wget xpra xserver-xorg-dev libglfw3-dev patchelf

#!sudo apt-get install -y libglew-dev
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# gcc is already the newest version (4:11.2.0-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 51 not upgraded.
# Reading package lists... Done
# E: You must put some 'deb-src' URIs in your sources.list
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# llvm-dev is already the newest version (1:14.0-55~exp2).
# 0 upgraded, 0 newly installed, 0 to remove and 51 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# freeglut3 is already the newest version (2.8.1-6).
# freeglut3-dev is already the newest version (2.8.1-6).
# 0 upgraded, 0 newly installed, 0 to remove and 51 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3-dev is already the newest version (3.10.6-1~22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 51 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# 0 upgraded, 0 newly installed, 0 to remove and 51 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libglew-dev is already the newest version (2.2.0-4).
# curl is already the newest version (7.81.0-1ubuntu1.19).
# git is already the newest version (1:2.34.1-1ubuntu1.11).
# libgl1-mesa-dev is already the newest version (23.2.1-1ubuntu3.1~22.04.3).
# libosmesa6-dev is already the newest version (23.2.1-1ubuntu3.1~22.04.3).
# software-properties-common is already the newest version (0.99.22.9).
# unzip is already the newest version (6.0-26ubuntu3.2).
# vim is already the newest version (2:8.2.3995-1ubuntu2.21).
# wget is already the newest version (1.21.2-2ubuntu1.1).
# libgl1-mesa-glx is already the newest version (23.0.4-0ubuntu1~22.04.1).
# The following additional packages will be installed:
#   gir1.2-appindicator3-0.1 gir1.2-atk-1.0 gir1.2-freedesktop
#   gir1.2-gdkpixbuf-2.0 gir1.2-gtk-3.0 gir1.2-harfbuzz-0.0 gir1.2-pango-1.0
#   keyboard-configuration libappindicator3-1 libdbusmenu-glib4
#   libdbusmenu-gtk3-4 libdrm-dev libegl1-mesa-dev libfontenc-dev libfontenc1
#   libglfw3 libimagequant0 liblocale-gettext-perl liblzo2-2 libpangoxft-1.0-0
#   libpciaccess-dev libpixman-1-dev libraqm0 libudev1 libvulkan-dev libvulkan1
#   libwayland-bin libwayland-dev libxcvt-dev libxcvt0 libxfont-dev libxfont2
#   libxkbfile-dev libxkbfile1 libxrandr-dev libxtst6 mailcap mesa-common-dev
#   mesa-vulkan-drivers mime-support python3-bcrypt python3-brotli python3-cairo
#   python3-cpuinfo python3-decorator python3-distlib python3-dns
#   python3-filelock python3-gssapi python3-ifaddr python3-kerberos python3-lz4
#   python3-lzo python3-nacl python3-numpy python3-olefile python3-opengl
#   python3-paramiko python3-pil python3-pip python3-pip-whl
#   python3-platformdirs python3-pyinotify python3-rencode python3-setproctitle
#   python3-setuptools python3-setuptools-whl python3-uritools
#   python3-virtualenv python3-wheel python3-wheel-whl python3-xdg
#   python3-zeroconf ssh-askpass systemd-hwe-hwdb udev x11-xkb-utils
#   x11-xserver-utils xcvt xfonts-base xfonts-encodings xfonts-utils
#   xserver-common xserver-xorg-core xserver-xorg-video-dummy xvfb
# Suggested packages:
#   indicator-application libglfw3-doc libwayland-doc python-nacl-doc
#   python-numpy-doc python3-pytest libgle3 python3-invoke python-pil-doc
#   python-pyinotify-doc python-setuptools-doc python2-pip-whl
#   python2-setuptools-whl nickle cairo-5c xorg-docs-core openssh-server
#   python3-pyopencl gstreamer1.0-plugins-base gstreamer1.0-plugins-good
#   | gstreamer1.0-plugins-ugly | gstreamer1.0-plugins-bad python3-gst-1.0
#   pulseaudio pulseaudio-utils python3-avahi python3-netifaces cups-client
#   cups-common cups-filters cups-pdf python3-cups python3-opencv
#   v4l2loopback-dkms python3-uinput xfonts-100dpi | xfonts-75dpi
#   xfonts-scalable
# The following NEW packages will be installed:
#   gir1.2-appindicator3-0.1 gir1.2-atk-1.0 gir1.2-freedesktop
#   gir1.2-gdkpixbuf-2.0 gir1.2-gtk-3.0 gir1.2-harfbuzz-0.0 gir1.2-pango-1.0
#   keyboard-configuration libappindicator3-1 libdbusmenu-glib4
#   libdbusmenu-gtk3-4 libdrm-dev libegl1-mesa-dev libfontenc-dev libfontenc1
#   libglfw3 libglfw3-dev libimagequant0 liblocale-gettext-perl liblzo2-2
#   libpangoxft-1.0-0 libpciaccess-dev libpixman-1-dev libraqm0 libvulkan-dev
#   libvulkan1 libwayland-bin libwayland-dev libxcvt-dev libxcvt0 libxfont-dev
#   libxfont2 libxkbfile-dev libxkbfile1 libxrandr-dev libxtst6 mailcap
#   mesa-common-dev mesa-vulkan-drivers mime-support net-tools patchelf
#   python3-bcrypt python3-brotli python3-cairo python3-cpuinfo
#   python3-decorator python3-distlib python3-dns python3-filelock
#   python3-gssapi python3-ifaddr python3-kerberos python3-lz4 python3-lzo
#   python3-nacl python3-numpy python3-olefile python3-opengl python3-paramiko
#   python3-pil python3-pip python3-pip-whl python3-platformdirs
#   python3-pyinotify python3-rencode python3-setproctitle python3-setuptools
#   python3-setuptools-whl python3-uritools python3-virtualenv python3-wheel
#   python3-wheel-whl python3-xdg python3-zeroconf ssh-askpass systemd-hwe-hwdb
#   udev virtualenv x11-xkb-utils x11-xserver-utils xcvt xfonts-base
#   xfonts-encodings xfonts-utils xpra xserver-common xserver-xorg-core
#   xserver-xorg-dev xserver-xorg-video-dummy xvfb
# The following packages will be upgraded:
#   libudev1
# 1 upgraded, 91 newly installed, 0 to remove and 50 not upgraded.
# Need to get 41.4 MB of archives.
# After this operation, 171 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblocale-gettext-perl amd64 1.07-4build3 [17.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 keyboard-configuration all 1.205ubuntu3 [206 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libudev1 amd64 249.11-0ubuntu3.12 [78.2 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 udev amd64 249.11-0ubuntu3.12 [1,557 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 gir1.2-atk-1.0 amd64 2.36.0-3build1 [21.0 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 gir1.2-freedesktop amd64 1.72.0-1 [22.3 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gir1.2-gdkpixbuf-2.0 amd64 2.42.8+dfsg-1ubuntu0.3 [9,486 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gir1.2-harfbuzz-0.0 amd64 2.7.4-1ubuntu3.1 [31.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpangoxft-1.0-0 amd64 1.50.6+ds-2ubuntu1 [31.0 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gir1.2-pango-1.0 amd64 1.50.6+ds-2ubuntu1 [44.0 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gir1.2-gtk-3.0 amd64 3.24.33-1ubuntu2.2 [240 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdbusmenu-glib4 amd64 16.04.1+18.10.20180917-0ubuntu8 [45.4 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdbusmenu-gtk3-4 amd64 16.04.1+18.10.20180917-0ubuntu8 [31.0 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libappindicator3-1 amd64 12.10.1+20.10.20200706.1-0ubuntu1 [23.2 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/universe amd64 gir1.2-appindicator3-0.1 amd64 12.10.1+20.10.20200706.1-0ubuntu1 [3,452 B]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpciaccess-dev amd64 0.16-3 [21.9 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdrm-dev amd64 2.4.113-2~ubuntu0.22.04.1 [292 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libegl1-mesa-dev amd64 23.2.1-1ubuntu3.1~22.04.3 [11.1 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc-dev amd64 1:1.1.4-1build3 [15.4 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libglfw3 amd64 3.3.6-1 [83.2 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libglfw3-dev amd64 3.3.6-1 [41.1 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libimagequant0 amd64 2.17.0-1 [34.6 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblzo2-2 amd64 2.10-2build3 [53.7 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpixman-1-dev amd64 0.40.0-1ubuntu0.22.04.1 [280 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 libraqm0 amd64 0.7.0-4ubuntu1 [11.7 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvulkan1 amd64 1.3.204.1-2 [128 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvulkan-dev amd64 1.3.204.1-2 [892 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcvt0 amd64 0.1.1-3 [5,494 B]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcvt-dev amd64 0.1.1-3 [3,242 B]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont-dev amd64 1:2.0.5-1build1 [128 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile-dev amd64 1:1.1.0-1build3 [85.0 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxrandr-dev amd64 2:1.5.2-1build1 [26.7 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/main amd64 mailcap all 3.70+nmu1ubuntu1 [23.8 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 mesa-common-dev amd64 23.2.1-1ubuntu3.1~22.04.3 [2,208 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 mesa-vulkan-drivers amd64 23.2.1-1ubuntu3.1~22.04.3 [10.7 MB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 mime-support all 3.66 [3,696 B]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/main amd64 net-tools amd64 1.60+git20181103.0eebece-1ubuntu5 [204 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/universe amd64 patchelf amd64 0.14.3-1 [72.1 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-brotli amd64 1.0.9-2build6 [319 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-cairo amd64 1.20.1-3build1 [73.7 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-cpuinfo all 5.0.0-2 [17.3 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-decorator all 4.4.2-0ubuntu1 [10.3 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-distlib all 0.3.4-1 [269 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-dns all 3.2.1-1 [25.6 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-filelock all 3.6.0-1 [8,788 B]
# Get:50 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-gssapi amd64 1.6.12-1ubuntu0.1 [368 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-ifaddr all 0.1.7-1 [8,492 B]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-kerberos amd64 1.1.14-3.1build5 [23.0 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-lz4 amd64 3.1.3+dfsg-1build3 [33.3 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-lzo amd64 1.12-4build1 [8,130 B]
# Get:55 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-nacl amd64 1.5.0-2 [63.1 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-numpy amd64 1:1.21.5-1ubuntu22.04.1 [3,467 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-olefile all 0.46-3 [33.8 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-opengl all 3.1.5+dfsg-1 [605 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-bcrypt amd64 3.2.0-1build1 [32.7 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-paramiko all 2.9.3-0ubuntu1.3 [134 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-pil amd64 9.0.1-1ubuntu0.3 [419 kB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-setuptools all 59.6.0-1.2ubuntu0.22.04.2 [340 kB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-wheel all 0.37.1-2ubuntu0.22.04.1 [32.0 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-pip all 22.0.2+dfsg-1ubuntu0.5 [1,306 kB]
# Get:65 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-pip-whl all 22.0.2+dfsg-1ubuntu0.5 [1,680 kB]
# Get:66 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-platformdirs all 2.5.1-1 [14.2 kB]
# Get:67 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-pyinotify all 0.9.6-1.3 [24.8 kB]
# Get:68 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-rencode amd64 1.0.6-2build1 [45.2 kB]
# Get:69 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-setuptools-whl all 59.6.0-1.2ubuntu0.22.04.2 [788 kB]
# Get:70 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-uritools all 3.0.2-1 [24.7 kB]
# Get:71 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-wheel-whl all 0.37.1-2ubuntu0.22.04.1 [38.0 kB]
# Get:72 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-virtualenv all 20.13.0+ds-2 [80.3 kB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-xdg all 0.27-2 [36.9 kB]
# Get:74 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-zeroconf all 0.38.3-2 [76.5 kB]
# Get:75 http://archive.ubuntu.com/ubuntu jammy/universe amd64 ssh-askpass amd64 1:1.2.4.1-13 [26.0 kB]
# Get:76 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 systemd-hwe-hwdb all 249.11.5 [3,228 B]
# Get:77 http://archive.ubuntu.com/ubuntu jammy/universe amd64 virtualenv all 20.13.0+ds-2 [1,968 B]
# Get:78 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xkb-utils amd64 7.7+5build4 [172 kB]
# Get:79 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xserver-utils amd64 7.7+9build1 [170 kB]
# Get:80 http://archive.ubuntu.com/ubuntu jammy/main amd64 xcvt amd64 0.1.1-3 [7,140 B]
# Get:81 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:82 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:83 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:84 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.12 [28.7 kB]
# Get:85 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-xorg-core amd64 2:21.1.4-2ubuntu1.7~22.04.12 [1,477 kB]
# Get:86 http://archive.ubuntu.com/ubuntu jammy/main amd64 xserver-xorg-video-dummy amd64 1:0.3.8-2build1 [9,578 B]
# Get:87 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 xvfb amd64 2:21.1.4-2ubuntu1.7~22.04.12 [864 kB]
# Get:88 http://archive.ubuntu.com/ubuntu jammy/universe amd64 xpra amd64 3.1-1build5 [3,396 kB]
# Get:89 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-xorg-dev amd64 2:21.1.4-2ubuntu1.7~22.04.12 [204 kB]
# Get:90 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwayland-bin amd64 1.20.0-1ubuntu0.1 [20.4 kB]
# Get:91 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwayland-dev amd64 1.20.0-1ubuntu0.1 [69.5 kB]
# Get:92 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-setproctitle amd64 1.2.2-2build1 [16.1 kB]
# Fetched 41.4 MB in 2s (18.8 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 92.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package liblocale-gettext-perl.
# (Reading database ... 127415 files and directories currently installed.)
# Preparing to unpack .../liblocale-gettext-perl_1.07-4build3_amd64.deb ...
# Unpacking liblocale-gettext-perl (1.07-4build3) ...
# Selecting previously unselected package keyboard-configuration.
# Preparing to unpack .../keyboard-configuration_1.205ubuntu3_all.deb ...
# Unpacking keyboard-configuration (1.205ubuntu3) ...
# Preparing to unpack .../libudev1_249.11-0ubuntu3.12_amd64.deb ...
# Unpacking libudev1:amd64 (249.11-0ubuntu3.12) over (249.11-0ubuntu3.10) ...
# Setting up libudev1:amd64 (249.11-0ubuntu3.12) ...
# Selecting previously unselected package udev.
# (Reading database ... 127449 files and directories currently installed.)
# Preparing to unpack .../00-udev_249.11-0ubuntu3.12_amd64.deb ...
# Unpacking udev (249.11-0ubuntu3.12) ...
# Selecting previously unselected package gir1.2-atk-1.0:amd64.
# Preparing to unpack .../01-gir1.2-atk-1.0_2.36.0-3build1_amd64.deb ...
# Unpacking gir1.2-atk-1.0:amd64 (2.36.0-3build1) ...
# Selecting previously unselected package gir1.2-freedesktop:amd64.
# Preparing to unpack .../02-gir1.2-freedesktop_1.72.0-1_amd64.deb ...
# Unpacking gir1.2-freedesktop:amd64 (1.72.0-1) ...
# Selecting previously unselected package gir1.2-gdkpixbuf-2.0:amd64.
# Preparing to unpack .../03-gir1.2-gdkpixbuf-2.0_2.42.8+dfsg-1ubuntu0.3_amd64.deb ...
# Unpacking gir1.2-gdkpixbuf-2.0:amd64 (2.42.8+dfsg-1ubuntu0.3) ...
# Selecting previously unselected package gir1.2-harfbuzz-0.0:amd64.
# Preparing to unpack .../04-gir1.2-harfbuzz-0.0_2.7.4-1ubuntu3.1_amd64.deb ...
# Unpacking gir1.2-harfbuzz-0.0:amd64 (2.7.4-1ubuntu3.1) ...
# Selecting previously unselected package libpangoxft-1.0-0:amd64.
# Preparing to unpack .../05-libpangoxft-1.0-0_1.50.6+ds-2ubuntu1_amd64.deb ...
# Unpacking libpangoxft-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Selecting previously unselected package gir1.2-pango-1.0:amd64.
# Preparing to unpack .../06-gir1.2-pango-1.0_1.50.6+ds-2ubuntu1_amd64.deb ...
# Unpacking gir1.2-pango-1.0:amd64 (1.50.6+ds-2ubuntu1) ...
# Selecting previously unselected package gir1.2-gtk-3.0:amd64.
# Preparing to unpack .../07-gir1.2-gtk-3.0_3.24.33-1ubuntu2.2_amd64.deb ...
# Unpacking gir1.2-gtk-3.0:amd64 (3.24.33-1ubuntu2.2) ...
# Selecting previously unselected package libdbusmenu-glib4:amd64.
# Preparing to unpack .../08-libdbusmenu-glib4_16.04.1+18.10.20180917-0ubuntu8_amd64.deb ...
# Unpacking libdbusmenu-glib4:amd64 (16.04.1+18.10.20180917-0ubuntu8) ...
# Selecting previously unselected package libdbusmenu-gtk3-4:amd64.
# Preparing to unpack .../09-libdbusmenu-gtk3-4_16.04.1+18.10.20180917-0ubuntu8_amd64.deb ...
# Unpacking libdbusmenu-gtk3-4:amd64 (16.04.1+18.10.20180917-0ubuntu8) ...
# Selecting previously unselected package libappindicator3-1.
# Preparing to unpack .../10-libappindicator3-1_12.10.1+20.10.20200706.1-0ubuntu1_amd64.deb ...
# Unpacking libappindicator3-1 (12.10.1+20.10.20200706.1-0ubuntu1) ...
# Selecting previously unselected package gir1.2-appindicator3-0.1.
# Preparing to unpack .../11-gir1.2-appindicator3-0.1_12.10.1+20.10.20200706.1-0ubuntu1_amd64.deb ...
# Unpacking gir1.2-appindicator3-0.1 (12.10.1+20.10.20200706.1-0ubuntu1) ...
# Selecting previously unselected package libpciaccess-dev:amd64.
# Preparing to unpack .../12-libpciaccess-dev_0.16-3_amd64.deb ...
# Unpacking libpciaccess-dev:amd64 (0.16-3) ...
# Selecting previously unselected package libdrm-dev:amd64.
# Preparing to unpack .../13-libdrm-dev_2.4.113-2~ubuntu0.22.04.1_amd64.deb ...
# Unpacking libdrm-dev:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Selecting previously unselected package libegl1-mesa-dev:amd64.
# Preparing to unpack .../14-libegl1-mesa-dev_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking libegl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../15-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libfontenc-dev:amd64.
# Preparing to unpack .../16-libfontenc-dev_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc-dev:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libglfw3:amd64.
# Preparing to unpack .../17-libglfw3_3.3.6-1_amd64.deb ...
# Unpacking libglfw3:amd64 (3.3.6-1) ...
# Selecting previously unselected package libglfw3-dev:amd64.
# Preparing to unpack .../18-libglfw3-dev_3.3.6-1_amd64.deb ...
# Unpacking libglfw3-dev:amd64 (3.3.6-1) ...
# Selecting previously unselected package libimagequant0:amd64.
# Preparing to unpack .../19-libimagequant0_2.17.0-1_amd64.deb ...
# Unpacking libimagequant0:amd64 (2.17.0-1) ...
# Selecting previously unselected package liblzo2-2:amd64.
# Preparing to unpack .../20-liblzo2-2_2.10-2build3_amd64.deb ...
# Unpacking liblzo2-2:amd64 (2.10-2build3) ...
# Selecting previously unselected package libpixman-1-dev:amd64.
# Preparing to unpack .../21-libpixman-1-dev_0.40.0-1ubuntu0.22.04.1_amd64.deb ...
# Unpacking libpixman-1-dev:amd64 (0.40.0-1ubuntu0.22.04.1) ...
# Selecting previously unselected package libraqm0:amd64.
# Preparing to unpack .../22-libraqm0_0.7.0-4ubuntu1_amd64.deb ...
# Unpacking libraqm0:amd64 (0.7.0-4ubuntu1) ...
# Selecting previously unselected package libvulkan1:amd64.
# Preparing to unpack .../23-libvulkan1_1.3.204.1-2_amd64.deb ...
# Unpacking libvulkan1:amd64 (1.3.204.1-2) ...
# Selecting previously unselected package libvulkan-dev:amd64.
# Preparing to unpack .../24-libvulkan-dev_1.3.204.1-2_amd64.deb ...
# Unpacking libvulkan-dev:amd64 (1.3.204.1-2) ...
# Selecting previously unselected package libxcvt0:amd64.
# Preparing to unpack .../25-libxcvt0_0.1.1-3_amd64.deb ...
# Unpacking libxcvt0:amd64 (0.1.1-3) ...
# Selecting previously unselected package libxcvt-dev:amd64.
# Preparing to unpack .../26-libxcvt-dev_0.1.1-3_amd64.deb ...
# Unpacking libxcvt-dev:amd64 (0.1.1-3) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../27-libxfont2_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.5-1build1) ...
# Selecting previously unselected package libxfont-dev.
# Preparing to unpack .../28-libxfont-dev_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont-dev (1:2.0.5-1build1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../29-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package libxkbfile-dev:amd64.
# Preparing to unpack .../30-libxkbfile-dev_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile-dev:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package libxrandr-dev:amd64.
# Preparing to unpack .../31-libxrandr-dev_2%3a1.5.2-1build1_amd64.deb ...
# Unpacking libxrandr-dev:amd64 (2:1.5.2-1build1) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../32-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package mailcap.
# Preparing to unpack .../33-mailcap_3.70+nmu1ubuntu1_all.deb ...
# Unpacking mailcap (3.70+nmu1ubuntu1) ...
# Selecting previously unselected package mesa-common-dev:amd64.
# Preparing to unpack .../34-mesa-common-dev_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking mesa-common-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Selecting previously unselected package mesa-vulkan-drivers:amd64.
# Preparing to unpack .../35-mesa-vulkan-drivers_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking mesa-vulkan-drivers:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Selecting previously unselected package mime-support.
# Preparing to unpack .../36-mime-support_3.66_all.deb ...
# Unpacking mime-support (3.66) ...
# Selecting previously unselected package net-tools.
# Preparing to unpack .../37-net-tools_1.60+git20181103.0eebece-1ubuntu5_amd64.deb ...
# Unpacking net-tools (1.60+git20181103.0eebece-1ubuntu5) ...
# Selecting previously unselected package patchelf.
# Preparing to unpack .../38-patchelf_0.14.3-1_amd64.deb ...
# Unpacking patchelf (0.14.3-1) ...
# Selecting previously unselected package python3-brotli.
# Preparing to unpack .../39-python3-brotli_1.0.9-2build6_amd64.deb ...
# Unpacking python3-brotli (1.0.9-2build6) ...
# Selecting previously unselected package python3-cairo:amd64.
# Preparing to unpack .../40-python3-cairo_1.20.1-3build1_amd64.deb ...
# Unpacking python3-cairo:amd64 (1.20.1-3build1) ...
# Selecting previously unselected package python3-cpuinfo.
# Preparing to unpack .../41-python3-cpuinfo_5.0.0-2_all.deb ...
# Unpacking python3-cpuinfo (5.0.0-2) ...
# Selecting previously unselected package python3-decorator.
# Preparing to unpack .../42-python3-decorator_4.4.2-0ubuntu1_all.deb ...
# Unpacking python3-decorator (4.4.2-0ubuntu1) ...
# Selecting previously unselected package python3-distlib.
# Preparing to unpack .../43-python3-distlib_0.3.4-1_all.deb ...
# Unpacking python3-distlib (0.3.4-1) ...
# Selecting previously unselected package python3-dns.
# Preparing to unpack .../44-python3-dns_3.2.1-1_all.deb ...
# Unpacking python3-dns (3.2.1-1) ...
# Selecting previously unselected package python3-filelock.
# Preparing to unpack .../45-python3-filelock_3.6.0-1_all.deb ...
# Unpacking python3-filelock (3.6.0-1) ...
# Selecting previously unselected package python3-gssapi.
# Preparing to unpack .../46-python3-gssapi_1.6.12-1ubuntu0.1_amd64.deb ...
# Unpacking python3-gssapi (1.6.12-1ubuntu0.1) ...
# Selecting previously unselected package python3-ifaddr.
# Preparing to unpack .../47-python3-ifaddr_0.1.7-1_all.deb ...
# Unpacking python3-ifaddr (0.1.7-1) ...
# Selecting previously unselected package python3-kerberos.
# Preparing to unpack .../48-python3-kerberos_1.1.14-3.1build5_amd64.deb ...
# Unpacking python3-kerberos (1.1.14-3.1build5) ...
# Selecting previously unselected package python3-lz4.
# Preparing to unpack .../49-python3-lz4_3.1.3+dfsg-1build3_amd64.deb ...
# Unpacking python3-lz4 (3.1.3+dfsg-1build3) ...
# Selecting previously unselected package python3-lzo:amd64.
# Preparing to unpack .../50-python3-lzo_1.12-4build1_amd64.deb ...
# Unpacking python3-lzo:amd64 (1.12-4build1) ...
# Selecting previously unselected package python3-nacl.
# Preparing to unpack .../51-python3-nacl_1.5.0-2_amd64.deb ...
# Unpacking python3-nacl (1.5.0-2) ...
# Selecting previously unselected package python3-numpy.
# Preparing to unpack .../52-python3-numpy_1%3a1.21.5-1ubuntu22.04.1_amd64.deb ...
# Unpacking python3-numpy (1:1.21.5-1ubuntu22.04.1) ...
# Selecting previously unselected package python3-olefile.
# Preparing to unpack .../53-python3-olefile_0.46-3_all.deb ...
# Unpacking python3-olefile (0.46-3) ...
# Selecting previously unselected package python3-opengl.
# Preparing to unpack .../54-python3-opengl_3.1.5+dfsg-1_all.deb ...
# Unpacking python3-opengl (3.1.5+dfsg-1) ...
# Selecting previously unselected package python3-bcrypt.
# Preparing to unpack .../55-python3-bcrypt_3.2.0-1build1_amd64.deb ...
# Unpacking python3-bcrypt (3.2.0-1build1) ...
# Selecting previously unselected package python3-paramiko.
# Preparing to unpack .../56-python3-paramiko_2.9.3-0ubuntu1.3_all.deb ...
# Unpacking python3-paramiko (2.9.3-0ubuntu1.3) ...
# Selecting previously unselected package python3-pil:amd64.
# Preparing to unpack .../57-python3-pil_9.0.1-1ubuntu0.3_amd64.deb ...
# Unpacking python3-pil:amd64 (9.0.1-1ubuntu0.3) ...
# Selecting previously unselected package python3-setuptools.
# Preparing to unpack .../58-python3-setuptools_59.6.0-1.2ubuntu0.22.04.2_all.deb ...
# Unpacking python3-setuptools (59.6.0-1.2ubuntu0.22.04.2) ...
# Selecting previously unselected package python3-wheel.
# Preparing to unpack .../59-python3-wheel_0.37.1-2ubuntu0.22.04.1_all.deb ...
# Unpacking python3-wheel (0.37.1-2ubuntu0.22.04.1) ...
# Selecting previously unselected package python3-pip.
# Preparing to unpack .../60-python3-pip_22.0.2+dfsg-1ubuntu0.5_all.deb ...
# Unpacking python3-pip (22.0.2+dfsg-1ubuntu0.5) ...
# Selecting previously unselected package python3-pip-whl.
# Preparing to unpack .../61-python3-pip-whl_22.0.2+dfsg-1ubuntu0.5_all.deb ...
# Unpacking python3-pip-whl (22.0.2+dfsg-1ubuntu0.5) ...
# Selecting previously unselected package python3-platformdirs.
# Preparing to unpack .../62-python3-platformdirs_2.5.1-1_all.deb ...
# Unpacking python3-platformdirs (2.5.1-1) ...
# Selecting previously unselected package python3-pyinotify.
# Preparing to unpack .../63-python3-pyinotify_0.9.6-1.3_all.deb ...
# Unpacking python3-pyinotify (0.9.6-1.3) ...
# Selecting previously unselected package python3-rencode.
# Preparing to unpack .../64-python3-rencode_1.0.6-2build1_amd64.deb ...
# Unpacking python3-rencode (1.0.6-2build1) ...
# Selecting previously unselected package python3-setuptools-whl.
# Preparing to unpack .../65-python3-setuptools-whl_59.6.0-1.2ubuntu0.22.04.2_all.deb ...
# Unpacking python3-setuptools-whl (59.6.0-1.2ubuntu0.22.04.2) ...
# Selecting previously unselected package python3-uritools.
# Preparing to unpack .../66-python3-uritools_3.0.2-1_all.deb ...
# Unpacking python3-uritools (3.0.2-1) ...
# Selecting previously unselected package python3-wheel-whl.
# Preparing to unpack .../67-python3-wheel-whl_0.37.1-2ubuntu0.22.04.1_all.deb ...
# Unpacking python3-wheel-whl (0.37.1-2ubuntu0.22.04.1) ...
# Selecting previously unselected package python3-virtualenv.
# Preparing to unpack .../68-python3-virtualenv_20.13.0+ds-2_all.deb ...
# Unpacking python3-virtualenv (20.13.0+ds-2) ...
# Selecting previously unselected package python3-xdg.
# Preparing to unpack .../69-python3-xdg_0.27-2_all.deb ...
# Unpacking python3-xdg (0.27-2) ...
# Selecting previously unselected package python3-zeroconf.
# Preparing to unpack .../70-python3-zeroconf_0.38.3-2_all.deb ...
# Unpacking python3-zeroconf (0.38.3-2) ...
# Selecting previously unselected package ssh-askpass.
# Preparing to unpack .../71-ssh-askpass_1%3a1.2.4.1-13_amd64.deb ...
# Unpacking ssh-askpass (1:1.2.4.1-13) ...
# Selecting previously unselected package systemd-hwe-hwdb.
# Preparing to unpack .../72-systemd-hwe-hwdb_249.11.5_all.deb ...
# Unpacking systemd-hwe-hwdb (249.11.5) ...
# Selecting previously unselected package virtualenv.
# Preparing to unpack .../73-virtualenv_20.13.0+ds-2_all.deb ...
# Unpacking virtualenv (20.13.0+ds-2) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../74-x11-xkb-utils_7.7+5build4_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5build4) ...
# Selecting previously unselected package x11-xserver-utils.
# Preparing to unpack .../75-x11-xserver-utils_7.7+9build1_amd64.deb ...
# Unpacking x11-xserver-utils (7.7+9build1) ...
# Selecting previously unselected package xcvt.
# Preparing to unpack .../76-xcvt_0.1.1-3_amd64.deb ...
# Unpacking xcvt (0.1.1-3) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../77-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../78-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../79-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../80-xserver-common_2%3a21.1.4-2ubuntu1.7~22.04.12_all.deb ...
# Unpacking xserver-common (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Selecting previously unselected package xserver-xorg-core.
# Preparing to unpack .../81-xserver-xorg-core_2%3a21.1.4-2ubuntu1.7~22.04.12_amd64.deb ...
# Unpacking xserver-xorg-core (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Selecting previously unselected package xserver-xorg-video-dummy.
# Preparing to unpack .../82-xserver-xorg-video-dummy_1%3a0.3.8-2build1_amd64.deb ...
# Unpacking xserver-xorg-video-dummy (1:0.3.8-2build1) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../83-xvfb_2%3a21.1.4-2ubuntu1.7~22.04.12_amd64.deb ...
# Unpacking xvfb (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Selecting previously unselected package xpra.
# Preparing to unpack .../84-xpra_3.1-1build5_amd64.deb ...
# Unpacking xpra (3.1-1build5) ...
# Selecting previously unselected package xserver-xorg-dev.
# Preparing to unpack .../85-xserver-xorg-dev_2%3a21.1.4-2ubuntu1.7~22.04.12_amd64.deb ...
# Unpacking xserver-xorg-dev (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Selecting previously unselected package libwayland-bin.
# Preparing to unpack .../86-libwayland-bin_1.20.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-bin (1.20.0-1ubuntu0.1) ...
# Selecting previously unselected package libwayland-dev:amd64.
# Preparing to unpack .../87-libwayland-dev_1.20.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-dev:amd64 (1.20.0-1ubuntu0.1) ...
# Selecting previously unselected package python3-setproctitle:amd64.
# Preparing to unpack .../88-python3-setproctitle_1.2.2-2build1_amd64.deb ...
# Unpacking python3-setproctitle:amd64 (1.2.2-2build1) ...
# Setting up python3-uritools (3.0.2-1) ...
# Setting up libglfw3:amd64 (3.3.6-1) ...
# Setting up net-tools (1.60+git20181103.0eebece-1ubuntu5) ...
# Setting up python3-setuptools-whl (59.6.0-1.2ubuntu0.22.04.2) ...
# Setting up python3-filelock (3.6.0-1) ...
# Setting up gir1.2-freedesktop:amd64 (1.72.0-1) ...
# Setting up libpixman-1-dev:amd64 (0.40.0-1ubuntu0.22.04.1) ...
# Setting up libpciaccess-dev:amd64 (0.16-3) ...
# Setting up python3-cairo:amd64 (1.20.1-3build1) ...
# Setting up python3-rencode (1.0.6-2build1) ...
# Setting up python3-setuptools (59.6.0-1.2ubuntu0.22.04.2) ...
# Setting up libpangoxft-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Setting up libglfw3-dev:amd64 (3.3.6-1) ...
# Setting up gir1.2-gdkpixbuf-2.0:amd64 (2.42.8+dfsg-1ubuntu0.3) ...
# Setting up python3-pip-whl (22.0.2+dfsg-1ubuntu0.5) ...
# Setting up python3-lz4 (3.1.3+dfsg-1build3) ...
# Setting up gir1.2-atk-1.0:amd64 (2.36.0-3build1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up python3-olefile (0.46-3) ...
# Setting up libdbusmenu-glib4:amd64 (16.04.1+18.10.20180917-0ubuntu8) ...
# Setting up python3-bcrypt (3.2.0-1build1) ...
# Setting up python3-pyinotify (0.9.6-1.3) ...
# Setting up python3-kerberos (1.1.14-3.1build5) ...
# Setting up liblzo2-2:amd64 (2.10-2build3) ...
# Setting up python3-distlib (0.3.4-1) ...
# Setting up python3-opengl (3.1.5+dfsg-1) ...
# Setting up python3-xdg (0.27-2) ...
# Setting up x11-xserver-utils (7.7+9build1) ...
# Setting up gir1.2-harfbuzz-0.0:amd64 (2.7.4-1ubuntu3.1) ...
# Setting up python3-wheel (0.37.1-2ubuntu0.22.04.1) ...
# Setting up python3-platformdirs (2.5.1-1) ...
# Setting up python3-ifaddr (0.1.7-1) ...
# Setting up libwayland-bin (1.20.0-1ubuntu0.1) ...
# Setting up python3-decorator (4.4.2-0ubuntu1) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up gir1.2-pango-1.0:amd64 (1.50.6+ds-2ubuntu1) ...
# Setting up libxrandr-dev:amd64 (2:1.5.2-1build1) ...
# Setting up ssh-askpass (1:1.2.4.1-13) ...
# update-alternatives: using /usr/lib/ssh/x11-ssh-askpass to provide /usr/bin/ssh-askpass (ssh-askpass) in auto mode
# Setting up python3-gssapi (1.6.12-1ubuntu0.1) ...
# Setting up python3-brotli (1.0.9-2build6) ...
# Setting up libraqm0:amd64 (0.7.0-4ubuntu1) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up libimagequant0:amd64 (2.17.0-1) ...
# Setting up python3-setproctitle:amd64 (1.2.2-2build1) ...
# Setting up udev (249.11-0ubuntu3.12) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up python3-pip (22.0.2+dfsg-1ubuntu0.5) ...
# Setting up python3-dns (3.2.1-1) ...
# Setting up python3-cpuinfo (5.0.0-2) ...
# Setting up python3-numpy (1:1.21.5-1ubuntu22.04.1) ...
# Setting up libvulkan1:amd64 (1.3.204.1-2) ...
# Setting up systemd-hwe-hwdb (249.11.5) ...
# Setting up libxcvt0:amd64 (0.1.1-3) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up patchelf (0.14.3-1) ...
# Setting up python3-wheel-whl (0.37.1-2ubuntu0.22.04.1) ...
# Setting up mailcap (3.70+nmu1ubuntu1) ...
# Setting up libxfont2:amd64 (1:2.0.5-1build1) ...
# Setting up liblocale-gettext-perl (1.07-4build3) ...
# Setting up python3-nacl (1.5.0-2) ...
# Setting up python3-lzo:amd64 (1.12-4build1) ...
# Setting up libxkbfile-dev:amd64 (1:1.1.0-1build3) ...
# Setting up libegl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up mesa-vulkan-drivers:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libdrm-dev:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Setting up libdbusmenu-gtk3-4:amd64 (16.04.1+18.10.20180917-0ubuntu8) ...
# Setting up libvulkan-dev:amd64 (1.3.204.1-2) ...
# Setting up libxcvt-dev:amd64 (0.1.1-3) ...
# Setting up mime-support (3.66) ...
# Setting up python3-zeroconf (0.38.3-2) ...
# Setting up x11-xkb-utils (7.7+5build4) ...
# Setting up gir1.2-gtk-3.0:amd64 (3.24.33-1ubuntu2.2) ...
# Setting up libfontenc-dev:amd64 (1:1.1.4-1build3) ...
# Setting up python3-virtualenv (20.13.0+ds-2) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up libwayland-dev:amd64 (1.20.0-1ubuntu0.1) ...
# Setting up libappindicator3-1 (12.10.1+20.10.20200706.1-0ubuntu1) ...
# Setting up xcvt (0.1.1-3) ...
# Setting up python3-pil:amd64 (9.0.1-1ubuntu0.3) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up gir1.2-appindicator3-0.1 (12.10.1+20.10.20200706.1-0ubuntu1) ...
# Setting up virtualenv (20.13.0+ds-2) ...
# Setting up mesa-common-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Setting up keyboard-configuration (1.205ubuntu3) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Configuring keyboard-configuration
# ----------------------------------
#
# The layout of keyboards varies per country, with some countries having multiple
# common layouts. Please select the country of origin for the keyboard of this
# computer.
#
#   1. Afghani
#   2. Albanian
#   3. Amharic
#   4. Arabic
#   5. Arabic (Morocco)
#   6. Arabic (Syria)
#   7. Armenian
#   8. A user-defined custom Layout
#   9. Azerbaijani
#   10. Bambara
#   11. Bangla
#   12. Belarusian
#   13. Belgian
#   14. Berber (Algeria, Latin)
#   15. Bosnian
#   16. Braille
#   17. Bulgarian
#   18. Burmese
#   19. Chinese
#   20. Croatian
#   21. Czech
#   22. Danish
#   23. Dhivehi
#   24. Dutch
#   25. Dzongkha
#   26. English (Australian)
#   27. English (Cameroon)
#   28. English (Ghana)
#   29. English (Nigeria)
#   30. English (South Africa)
#   31. English (UK)
#   32. English (US)
#   33. Esperanto
#   34. Estonian
#   35. Faroese
#   36. Filipino
#   37. Finnish
#   38. French
#   39. French (Canada)
#   40. French (Democratic Republic of the Congo)
#   41. French (Togo)
#   42. Georgian
#   43. German
#   44. German (Austria)
#   45. Greek
#   46. Hebrew
#   47. Hungarian
#   48. Icelandic
#   49. Indian
#   50. Indonesian (Javanese)
#   51. Indonesian (Latin)
#   52. Iraqi
#   53. Irish
#   54. Italian
#   55. Japanese
#   56. Japanese (PC-98)
#   57. Kazakh
#   58. Khmer (Cambodia)
#   59. Korean
#   60. Kyrgyz
#   61. Lao
#   62. Latvian
#   63. Lithuanian
#   64. Macedonian
#   65. Malay (Jawi, Arabic Keyboard)
#   66. Maltese
#   67. Maori
#   68. Moldavian
#   69. Mongolian
#   70. Montenegrin
#   71. Nepali
#   72. NKo (AZERTY)
#   73. Norwegian
#   74. Persian
#   75. Polish
#   76. Portuguese
#   77. Portuguese (Brazil)
#   78. Romanian
#   79. Russian
#   80. Serbian
#   81. Sinhala (phonetic)
#   82. Slovak
#   83. Slovenian
#   84. Spanish
#   85. Spanish (Latin American)
#   86. Swahili (Kenya)
#   87. Swahili (Tanzania)
#   88. Swedish
#   89. Switzerland
#   90. Taiwanese
#   91. Tajik
#   92. Thai
#   93. Tswana
#   94. Turkish
#   95. Turkmen
#   96. Ukrainian
#   97. Urdu (Pakistan)
#   98. Uzbek
#   99. Vietnamese
#   100. Wolof
# Country of origin for the keyboard: 32
#
# Please select the layout matching the keyboard for this machine.
#
#   1. English (US)
#   2. English (US) - Cherokee
#   3. English (US) - English (classic Dvorak)
#   4. English (US) - English (Colemak)
#   5. English (US) - English (Colemak-DH)
#   6. English (US) - English (Colemak-DH ISO)
#   7. English (US) - English (Dvorak)
#   8. English (US) - English (Dvorak, alt. intl.)
#   9. English (US) - English (Dvorak, intl., with dead keys)
#   10. English (US) - English (Dvorak, left-handed)
#   11. English (US) - English (Dvorak, right-handed)
#   12. English (US) - English (intl., with AltGr dead keys)
#   13. English (US) - English (Macintosh)
#   14. English (US) - English (Norman)
#   15. English (US) - English (programmer Dvorak)
#   16. English (US) - English (the divide/multiply toggle the layout)
#   17. English (US) - English (US, alt. intl.)
#   18. English (US) - English (US, euro on 5)
#   19. English (US) - English (US, intl., with dead keys)
#   20. English (US) - English (US, Symbolic)
#   21. English (US) - English (Workman)
#   22. English (US) - English (Workman, intl., with dead keys)
#   23. English (US) - Hawaiian
#   24. English (US) - Russian (US, phonetic)
#   25. English (US) - Serbo-Croatian (US)
# Keyboard layout: 1
#
# Your console font configuration will be updated the next time your system
# boots. If you want to update it now, run 'setupcon' from a virtual console.
# Setting up python3-paramiko (2.9.3-0ubuntu1.3) ...
# Setting up xvfb (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Setting up libxfont-dev (1:2.0.5-1build1) ...
# Setting up xserver-xorg-core (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Setting up xserver-xorg-video-dummy (1:0.3.8-2build1) ...
# Setting up xserver-xorg-dev (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Setting up xpra (3.1-1build5) ...
# .+...+...+...+..+...+....+.....+.......+........+...+...+.......+..+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++*.+.+.....+.........+......+.+..+.+..+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++*........+.............+..+...+....+...+...+......+.....+....+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...+....+..+..........+..+............+....+........................+.....+.......+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++*.....+...+...+.......+..............+...+.......+.....+......+............+......+......+....+.....+......+.+...+..............+..........+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++*...+........+....+..............+............+.......+..+................+..+..........+...+...+....................+............+.......+..+.+...+.....+......+....+.........+......+..+....+...+.....+......................+.....+.+...+.....+...........................+.........+.+..+.+......+...........+....+...............+.....+.........+.........+.+..............+.......+......+........+.......+...+..............+.+.....+.+...+............+.....+...+.............+..+............+.+..+...+..........+...+.........+..+...+............+.........+.+.......................+.......+........+...+....+...+...............+......+.....+....+...+..+.+..............+...............+...+............+................+......+.....+......+.......+...+.....+...+......+.+............+........+.......+......+.....+......................+...+..+...+...............+.+...+..+....+...........+.............+...............+.....+......+......+.....................+..........+..+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# -----
# Processing triggers for dbus (1.12.20-2ubuntu4.1) ...
# Processing triggers for shared-mime-info (2.1-2) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !nvidia-smi
# Out:
# Sun Dec 15 05:36:24 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
###### mujoco setup ######


#!wget https://mujoco.org/download/mujoco210-linux-x86_64.tar.gz

# !wget https://roboti.us/download/mujoco200_linux.zip

# !wget https://roboti.us/file/mjkey.txt
# Out:
# --2024-12-15 05:36:24--  https://roboti.us/download/mujoco200_linux.zip
# Resolving roboti.us (roboti.us)... 104.40.85.93
# Connecting to roboti.us (roboti.us)|104.40.85.93|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4427362 (4.2M) [application/zip]
# Saving to: ‘mujoco200_linux.zip.1’
#
# mujoco200_linux.zip 100%[===================>]   4.22M  --.-KB/s    in 0.1s
#
# 2024-12-15 05:36:24 (29.8 MB/s) - ‘mujoco200_linux.zip.1’ saved [4427362/4427362]
#
# --2024-12-15 05:36:24--  https://roboti.us/file/mjkey.txt
# Resolving roboti.us (roboti.us)... 104.40.85.93
# Connecting to roboti.us (roboti.us)|104.40.85.93|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 768 [text/plain]
# Saving to: ‘mjkey.txt’
#
# mjkey.txt           100%[===================>]     768  --.-KB/s    in 0s
#
# 2024-12-15 05:36:24 (76.2 MB/s) - ‘mjkey.txt’ saved [768/768]

# %%
# !mkdir /root/.mujoco

### mujoco 210
#!tar -xf mujoco210-linux-x86_64.tar.gz -C /.mujoco/
#!ls -alh /.mujoco/mujoco210

### mujoco 200
# !unzip mujoco200_linux.zip -d /root/.mujoco/
# !cp -r /root/.mujoco/mujoco200_linux /root/.mujoco/mujoco200

# !mv mjkey.txt /root/.mujoco/

# !cp -r /root/.mujoco/mujoco200/bin/* /usr/lib/
# Out:
# mkdir: cannot create directory ‘/root/.mujoco’: File exists
# Archive:  mujoco200_linux.zip
# replace /root/.mujoco/mujoco200_linux/sample/mjxmake.m? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
# !ls -alh /root/.mujoco/
# Out:
# total 24K
# drwxr-xr-x 4 root root 4.0K Dec 15 05:37 .
# drwx------ 1 root root 4.0K Dec 15 05:29 ..
# -rw-r--r-- 1 root root  768 Oct 18  2021 mjkey.txt
# drwxr-xr-x 8 root root 4.0K Dec 15 05:37 mujoco200
# drwxrwxr-x 7 root root 4.0K Oct  2  2018 mujoco200_linux

# %%
###### mujoco-py setup ######

# !pip install mujoco_py==2.0.2.8
# Out:
# Requirement already satisfied: mujoco_py==2.0.2.8 in /usr/local/lib/python3.10/dist-packages (2.0.2.8)
# Requirement already satisfied: glfw>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from mujoco_py==2.0.2.8) (2.8.0)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.10/dist-packages (from mujoco_py==2.0.2.8) (1.26.4)
# Requirement already satisfied: Cython>=0.27.2 in /usr/local/lib/python3.10/dist-packages (from mujoco_py==2.0.2.8) (0.29.37)
# Requirement already satisfied: imageio>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from mujoco_py==2.0.2.8) (2.36.1)
# Requirement already satisfied: cffi>=1.10 in /usr/local/lib/python3.10/dist-packages (from mujoco_py==2.0.2.8) (1.17.1)
# Requirement already satisfied: fasteners~=0.15 in /usr/local/lib/python3.10/dist-packages (from mujoco_py==2.0.2.8) (0.19)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.10->mujoco_py==2.0.2.8) (2.22)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio>=2.1.2->mujoco_py==2.0.2.8) (11.0.0)

# %%
###### D4RL setup ######

## !pip uninstall dm_control==0.0.364896371
# !git clone https://github.com/WhyAreYouJay/d4rl_benchmark_eval.git

# !git clone https://github.com/rail-berkeley/d4rl.git

### edit dm_control version in d4rl setup.py
# !sed -i "s;dm_control @ git+git://github.com/deepmind/dm_control@master#egg=dm_control;dm_control==0.0.364896371;g" /content/d4rl/setup.py

### edit mjrl install in d4rl setup.py to use github's new https protocol instead of git SSH
# !sed -i "s;mjrl @ git+git://github.com/aravindr93/mjrl@master#egg=mjrl;mjrl @ git+https://github.com/aravindr93/mjrl@master#egg=mjrl;g" /content/d4rl/setup.py

# !pip install -e d4rl/.

# !pip install "cython<3"
# Out:
# fatal: destination path 'd4rl_benchmark_eval' already exists and is not an empty directory.
# fatal: destination path 'd4rl' already exists and is not an empty directory.
# Obtaining file:///content/d4rl
#   Preparing metadata (setup.py) ... done
# Collecting mjrl@ git+https://github.com/aravindr93/mjrl@master#egg=mjrl (from D4RL==1.1)
#   Cloning https://github.com/aravindr93/mjrl (to revision master) to /tmp/pip-install-oc1zuagj/mjrl_c9c24ed462b64fa3ac4072cc02dc8df6
#   Running command git clone --filter=blob:none --quiet https://github.com/aravindr93/mjrl /tmp/pip-install-oc1zuagj/mjrl_c9c24ed462b64fa3ac4072cc02dc8df6
#   Resolved https://github.com/aravindr93/mjrl to commit 3871d93763d3b49c4741e6daeaebbc605fe140dc
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gym<0.24.0 in /usr/local/lib/python3.10/dist-packages (from D4RL==1.1) (0.23.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from D4RL==1.1) (1.26.4)
# Requirement already satisfied: mujoco_py in /usr/local/lib/python3.10/dist-packages (from D4RL==1.1) (2.0.2.8)
# Requirement already satisfied: pybullet in /usr/local/lib/python3.10/dist-packages (from D4RL==1.1) (3.2.6)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from D4RL==1.1) (3.12.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from D4RL==1.1) (2.5.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from D4RL==1.1) (8.1.7)
# Requirement already satisfied: dm_control>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from D4RL==1.1) (1.0.26)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (1.4.0)
# Requirement already satisfied: dm-env in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (1.6)
# Requirement already satisfied: dm-tree!=0.1.2 in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (0.1.8)
# Requirement already satisfied: glfw in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (2.8.0)
# Requirement already satisfied: labmaze in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (1.0.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (5.3.0)
# Requirement already satisfied: mujoco>=3.2.6 in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (3.2.6)
# Requirement already satisfied: protobuf>=3.19.4 in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (4.25.5)
# Requirement already satisfied: pyopengl>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (3.1.7)
# Requirement already satisfied: pyparsing>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (3.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (2.32.3)
# Requirement already satisfied: setuptools!=50.0.0 in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (75.1.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (1.13.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (4.66.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym<0.24.0->D4RL==1.1) (3.1.0)
# Requirement already satisfied: gym_notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym<0.24.0->D4RL==1.1) (0.0.8)
# Requirement already satisfied: Cython>=0.27.2 in /usr/local/lib/python3.10/dist-packages (from mujoco_py->D4RL==1.1) (0.29.37)
# Requirement already satisfied: imageio>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from mujoco_py->D4RL==1.1) (2.36.1)
# Requirement already satisfied: cffi>=1.10 in /usr/local/lib/python3.10/dist-packages (from mujoco_py->D4RL==1.1) (1.17.1)
# Requirement already satisfied: fasteners~=0.15 in /usr/local/lib/python3.10/dist-packages (from mujoco_py->D4RL==1.1) (0.19)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.10->mujoco_py->D4RL==1.1) (2.22)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio>=2.1.2->mujoco_py->D4RL==1.1) (11.0.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.10/dist-packages (from mujoco>=3.2.6->dm_control>=1.0.3->D4RL==1.1) (1.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->dm_control>=1.0.3->D4RL==1.1) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->dm_control>=1.0.3->D4RL==1.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->dm_control>=1.0.3->D4RL==1.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->dm_control>=1.0.3->D4RL==1.1) (2024.8.30)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=3.2.6->dm_control>=1.0.3->D4RL==1.1) (2024.10.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=3.2.6->dm_control>=1.0.3->D4RL==1.1) (6.4.5)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=3.2.6->dm_control>=1.0.3->D4RL==1.1) (4.12.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=3.2.6->dm_control>=1.0.3->D4RL==1.1) (3.21.0)
# Installing collected packages: D4RL
#   Attempting uninstall: D4RL
#     Found existing installation: D4RL 1.1
#     Uninstalling D4RL-1.1:
#       Successfully uninstalled D4RL-1.1
#   Running setup.py develop for D4RL
# Successfully installed D4RL-1.1
# Requirement already satisfied: cython<3 in /usr/local/lib/python3.10/dist-packages (0.29.37)

# %%
###### restart runtime ######

exit()

# %%
# !pip install gymnasium
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (0.0.4)

# %%
# !git -C d4rl_benchmark_eval/ fetch
# !git -C d4rl_benchmark_eval/ pull
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 1.05 KiB | 1.05 MiB/s, done.
# From https://github.com/WhyAreYouJay/d4rl_benchmark_eval
#    f2aeb5c..5579039  main       -> origin/main
# Updating f2aeb5c..5579039
# Fast-forward
#  deep_learning_rl_sm/neuralnets/minGRU_Reinformer.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !nvidia-smi
# Out:
# Sun Dec 15 05:37:24 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# %env LD_LIBRARY_PATH=/usr/lib64-nvidia:/root/.mujoco/mujoco200/bin
# Out:
# env: LD_LIBRARY_PATH=/usr/lib64-nvidia:/root/.mujoco/mujoco200/bin

# %%
# !echo $LD_LIBRARY_PATH
# Out:
# /usr/lib64-nvidia:/root/.mujoco/mujoco200/bin

# %% [markdown]
# V1 7min 500 its
# V1 7min 450 its

# %%
# !python d4rl_benchmark_eval/train_benchmark.py
# Out:
# Iteration 1
# Iteration 51
# Iteration 101
# Iteration 151
# Iteration 201
# Iteration 251
# Iteration 301
# Iteration 351
# Iteration 401
# Iteration 451
# Traceback (most recent call last):
#   File "/content/d4rl_benchmark_eval/train_benchmark.py", line 176, in <module>
#     outputs = trainer.train_iteration_benchmark(num_steps=args['num_steps_per_iter'], iter_num=it+1, print_logs=True)
#   File "/content/d4rl_benchmark_eval/deep_learning_rl_sm/trainer/trainer.py", line 324, in train_iteration_benchmark
#     train_loss = self.train_step_benchmark()
#   File "/content/d4rl_benchmark_eval/deep_learning_rl_sm/trainer/trainer.py", line 411, in train_step_benchmark
#     loss.backward()
#   File "/usr/local/lib/python3.10/dist-packages/torch/_tensor.py", line 581, in backward
#     torch.autograd.backward(
#   File "/usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py", line 347, in backward
#     _engine_run_backward(
#   File "/usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py", line 825, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# KeyboardInterrupt
